# %% [markdown]
# <a href="https://colab.research.google.com/github/vasavi2015/PHYTON/blob/main/Matplotlib_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['Chem','Clad','C lang','Single','Several','Workshop','Venture','IT' ])
ypoints = np.array([94,86,91,85,94,98,74,89 ])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([94,86,91,85,94,98,74,89 ])
mylabels = ['Chem','CLAD','C lang','Single','Several','Workshop','Venture','IT' ]

plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([94,86,91,85,94,98,74,89 ])
mylabels = ['Chem','CLAD','C lang','Single','Several','Workshop','Venture','IT' ]

plt.pie(y, labels = mylabels, startangle = 180)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['Chem','Clad','C lang','math1','math2','Workshop','Venture','IT'])
y = np.array([94,86,91,85,94,98,74,89])

plt.bar(x,y)
plt.show()
